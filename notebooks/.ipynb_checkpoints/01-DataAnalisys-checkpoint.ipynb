# %% [markdown]
# <b>Author:</b> Reinaldo Maciel <br>
# <b>Date:</b> Dec, 1st 2021 <br>
# <b>Summary:</b> This notebook makes an EDA analysis on bike sharing data.

# %% [markdown]
# ### List of contents
# - Motivation
# - Importing Libraries
# - Load Data
# - EDA

# %% [markdown]
# ### Motivation

# %% [markdown]
# As part of Udacity data science nanodegree project evaluation, this analysis was made in order to accomplish the task of taking an open dataset and apply several concepts learned in the first module of the program.
# The chosen dataset was the bike sharing dataset, available on
# <https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset>.
# Some of the business questions made on this dataset, and that this notebook tries to answer are:
#
# - What are the set of variables that mostly explain the total of rental bikes?
# - Given that set of variables, what are the best situation that increase the number of registered rentals per hour?
# - Is it possible to predict the number of registered rentals per day or per hour?

# %% [markdown]
# ### 01.Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../src')
import getData
import seaborn as sns
import Utils as ut

# %% [markdown]
# ### 02. Load data

# %%
#getData.download()
df_hour = pd.read_csv('../data/BSD/hour.csv')
df_day = pd.read_csv('../data/BSD/day.csv')

# %%
df_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df_day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### 03.EDA

# %%
### Dataset Size
print('Size of hour dataset: ', df_hour.shape)
print('Size of day dataset: ', df_day.shape)
# Out:
# Size of hour dataset:  (17379, 17)
# Size of day dataset:  (731, 16)

# %%
### Volume of missing data by column HOUR DF
df_hour.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
### Volume of missing data by column DAY DF
df_day.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
### DF_HOUR DATATYPES
df_hour.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
### DF_Day DATATYPES
df_day.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# #### 03.1 Converting dates from objects to date
#
# Some dates are not formatted as expected, so let's format it properly.

# %%
df_hour.dteday = pd.to_datetime(df_hour.dteday, format='%Y-%m-%d')
df_day.dteday = pd.to_datetime(df_day.dteday, format='%Y-%m-%d')

# %% [markdown]
# #### 03.2 Correlation between Numeric variables and target
#
#
# As part of understanding if the total rental of bikes can be explained by other variables, the correlation below is a way to understand how the numerical variables are correlated with the total amount of rentals.
# I'm going to work for now with the hourly dataset, since the daily is only an aggregation, and the results would be similar.

# %%
df_hour[['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']].corr()
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.987672 -0.069881  -0.023125  0.459616    0.335361
# atemp       0.987672  1.000000 -0.051918  -0.062336  0.454080    0.332559
# hum        -0.069881 -0.051918  1.000000  -0.290105 -0.347028   -0.273933
# windspeed  -0.023125 -0.062336 -0.290105   1.000000  0.090287    0.082321
# casual      0.459616  0.454080 -0.347028   0.090287  1.000000    0.506618
# registered  0.335361  0.332559 -0.273933   0.082321  0.506618    1.000000
# cnt         0.404772  0.400929 -0.322911   0.093234  0.694564    0.972151
#
#                  cnt
# temp        0.404772
# atemp       0.400929
# hum        -0.322911
# windspeed   0.093234
# casual      0.694564
# registered  0.972151
# cnt         1.000000

# %% [markdown]
# The plot below only show us the same information as the table above, except that visually we can see faster which are the correlated variables.

# %%
sns.heatmap(df_hour[['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']]\
    .corr()).set_title('Correlation between numeric vars');

# %% [markdown]
# The plot belows implements a kernel density estimate (KDE) plot, that is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
sns.pairplot(df_hour[['temp', 'atemp', 'hum','casual', 'registered' ,'windspeed', 'cnt']], kind='kde');

# %% [markdown]
# #### 03.3 Conclusions:
#
# So far, it's possible to notice that some numerical variables have high correlation, because they're almost the same thing. That states as true for:
# - temp and atemp;
# - casual and cnt;
# - registered and cnt;
#
# Despite of that high correlation, all of this variables will be kept in the dataset.

# %% [markdown]
# #### 03.4 Correlation between cat vars
#
# Almost the same approach will be taken for categorical variables:
# - First see what are the correlation between them;
# - Evaluate how each categorial variable are distributed along the volume of rentals

# %%
df_hour.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# The categorical variables are writen as numbers. We will apply a function to bring their categorical value to the dataset.

# %%
w = ut.Utils(df_hour)
df_hour_spine = w.NameCategoricals()

# %%
df_hour_spine.head()
# Out:
#    instant     dteday  season  yr     mnth  hr       holiday   weekday  \
# 0        1 2011-01-01  winter   0  january   0  business day  saturday
# 1        2 2011-01-01  winter   0  january   1  business day  saturday
# 2        3 2011-01-01  winter   0  january   2  business day  saturday
# 3        4 2011-01-01  winter   0  january   3  business day  saturday
# 4        5 2011-01-01  winter   0  january   4  business day  saturday
#
#    workingday weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0           0      clear  0.24  0.2879  0.81        0.0       3          13
# 1           0      clear  0.22  0.2727  0.80        0.0       8          32
# 2           0      clear  0.22  0.2727  0.80        0.0       5          27
# 3           0      clear  0.24  0.2879  0.75        0.0       3          10
# 4           0      clear  0.24  0.2879  0.75        0.0       0           1
#
#    cnt
# 0   16
# 1   40
# 2   32
# 3   13
# 4    1

# %% [markdown]
# Now, I'm creating a dataframe to store all the correlations that are going to be calculated for all the categorical variables.

# %%
df_categorical_correlations = pd.DataFrame(columns=['X','Y','value'])

# %%
cat_vars = ['season','yr' ,'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

# %%
ls = []
ls_cols = []
ls_vals = []
for j in range(0, len(cat_vars)):
    for i in range(j+1, len(cat_vars)):
        ls.append([cat_vars[j], cat_vars[i]])

for vals in ls:
    ls_cols.append(vals[0]+'-'+vals[1])
    ls_vals.append(ut.crammers_v(df_hour_spine[vals[0]], df_hour_spine[vals[1]]))
df_correlation_cat = pd.DataFrame.from_dict({'cat_var_pair':ls_cols, 'correlation':ls_vals})

# %%
df_correlation_cat.sort_values(by='correlation', ascending=False, inplace=True)

# %% [markdown]
# The plot below show the pair of variables that have the greatest correlation.

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Greatest Crammers_V correlation on Categorical Variables')
plt.xlabel('Crammers_V value')
plt.ylabel('Categorical Variable Pair')
ax = sns.barplot(ax = ax, x=df_correlation_cat['correlation'], y=df_correlation_cat['cat_var_pair'])

# %% [markdown]
# #### 03.5 Conclusions:
#
# - For categorical variables we have pairs of variables that obviously have a high correlation (for example, great part of the workingdays are weekdays);
# - Most of those correlations are related to time based variables, exception for wheathersit.
# - hr, as the most granular piece of information related to time, have no correlation with other time variable. That's because every time variable has hour on its composition.
#
# Even with hr showing to be a very weak variable in comparison with other categoricals, it's going to be kept in the dataset.
